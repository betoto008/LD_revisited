# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_ens = np.loadtxt('../Simulations/Text_files/Ensemble/K_ensemble_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep1.txt')
data = np.loadtxt('../Simulations/Text_files/One_pop/One_pop_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep0.txt', delimiter=',')
data2 = np.loadtxt('../Simulations/Text_files/One_pop/One_pop_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep1.txt', delimiter=',')
data3 = np.loadtxt('../Simulations/Text_files/One_pop/One_pop_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep2.txt', delimiter=',')
#data_const = np.loadtxt('../Simulations/Text_files/One_pop/One_pop_mu1.0e-05_s0.0e+00_C1.0e+06_N01.0e+06_L1_G010_rep0.txt', delimiter=',')
data_stats = np.loadtxt('../Simulations/Text_files/Stats/K_ensemble_stat_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep0.txt')
data_stats2 = np.loadtxt('../Simulations/Text_files/Stats/K_ensemble_stat_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep1.txt')
data_stats3 = np.loadtxt('../Simulations/Text_files/Stats/K_ensemble_stat_mu1.0e-05_s0.0e+00_C1.0e+05_N01.0e+00_L1_G010_rep2.txt')

# %%
plt.plot(data[:,0], data[:,3], 'r')
#plt.plot(data_const[:,0], data_const[:,3], 'r')
plt.plot(data2[:,0], data2[:,3], 'r')
plt.plot(data3[:,0], data3[:,3], 'r')
plt.plot(data_ens[:,0], data_ens[:,1])
#plt.yscale('log')

# %%
plt.plot(data[:,0], data[:,1],'r')
#plt.plot(data_const[:,0], data_const[:,1],'r')
plt.plot(data2[:,0], data2[:,1],'r')
plt.plot(data_ens[:,0], data_ens[:,3])
plt.yscale('log')

# %%
plt.figure(figsize=(20,10))
#plt.hist(data_stats2[:,1], alpha =.5, bins = 100, density=True);
#plt.hist(data_stats3[:,1], alpha =.5, bins = 100, density=True);
n,b,p = plt.hist(data_stats[:,1], alpha =.5, bins = 1200, density=True);


xx = (b[:-1]+b[1:])/2
plaw_2 = xx**(-2)
mu = 1e-5
N_curr = 1e4
K=1e5
plaw_1 = xx**(-1+2*N_curr*mu)
plt.plot(xx, plaw_1 * n[0]/plaw_1[0],label = '$x^{-1+2N\mu}$')
plt.plot(xx, plaw_2 * n[0]/plaw_2[0],label = '$x^{-2}$')
plt.legend(loc='best', fontsize = 30)
plt.axvline(x= mu*np.log(K))
plt.xlim(1E-5,0.005)
#plt.xscale('log')
#plt.yscale('log')
# Out:
# (1e-05, 0.005)

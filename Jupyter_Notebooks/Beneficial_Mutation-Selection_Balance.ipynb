# %%
import sys
sys.path.append('../Codes/Python/')

# %%
from fate_single_mut import *

# %%
s = 0.09
fate_single_mut(s, 20, short_t = False, long_t = True)
